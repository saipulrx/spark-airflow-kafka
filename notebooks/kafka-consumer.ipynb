# %%
import json
import uuid
import os
import json
from dotenv import load_dotenv
from pathlib import Path
from kafka import KafkaProducer
from faker import Faker
from time import sleep

# %%
dotenv_path = Path('/resources/.env')
load_dotenv(dotenv_path=dotenv_path)
# Out:
# True

# %%
kafka_host = os.getenv('KAFKA_HOST')
kafka_topic = os.getenv('KAFKA_TOPIC_NAME')
kafka_topic_partition = os.getenv('KAFKA_TOPIC_NAME')+"-1"

# %%
from kafka import KafkaConsumer

# To consume latest messages and auto-commit offsets
consumer = KafkaConsumer(kafka_topic_partition,
                         group_id='dibimbing-group',
                         bootstrap_servers=[f'{kafka_host}:9092'])

# %%
for message in consumer:
    print ("%s:%d:%d: key=%s value=%s" % (message.topic, message.partition,
                                          message.offset, message.key,
                                          message.value))
# Out:
# create_topic-1:0:38: key=None value=b'{"emp_id": "1c818ab4-0976-4f70-8821-519525eaa40d", "employee_name": "Jeremy Cannon", "department": "IT", "state": "TX", "salary": 93335, "age": 41, "bonus": 43708, "ts": 1557122043}'
# create_topic-1:0:39: key=None value=b'{"emp_id": "758943a1-8ba8-413d-af79-4ef793bec4d7", "employee_name": "Suzanne Baker", "department": "Marketing", "state": "TX", "salary": 52346, "age": 40, "bonus": 40159, "ts": 260809813}'
# create_topic-1:0:40: key=None value=b'{"emp_id": "34bd6574-889f-47e0-a935-2a26c7bfa746", "employee_name": "Joshua Thompson", "department": "Marketing", "state": "TX", "salary": 111893, "age": 50, "bonus": 5925, "ts": 1174775271}'
# create_topic-1:0:41: key=None value=b'{"emp_id": "29b28c4c-c260-4ea4-aa0c-4df315109e6d", "employee_name": "David Spencer", "department": "Sales", "state": "FL", "salary": 22597, "age": 31, "bonus": 82372, "ts": 460304777}'
# create_topic-1:0:42: key=None value=b'{"emp_id": "0f9f92a3-9595-44f6-8a62-167762ffcc49", "employee_name": "Daniel Bright", "department": "Marketing", "state": "FL", "salary": 94217, "age": 36, "bonus": 22167, "ts": 454729524}'
# create_topic-1:0:43: key=None value=b'{"emp_id": "17396293-7ac8-4bd7-8405-a230193ae15f", "employee_name": "Tristan Andrews", "department": "Sales", "state": "IL", "salary": 82681, "age": 36, "bonus": 57064, "ts": 537118210}'
# create_topic-1:0:44: key=None value=b'{"emp_id": "754c3ef4-c3da-45f7-9698-c9dc68446b55", "employee_name": "Madison Cruz", "department": "Sales", "state": "NY", "salary": 125981, "age": 55, "bonus": 71002, "ts": 479259472}'
# create_topic-1:0:45: key=None value=b'{"emp_id": "6c747ecc-685a-4c01-b3f2-19541b0f0659", "employee_name": "Melissa Davis", "department": "Marketing", "state": "RJ", "salary": 129142, "age": 36, "bonus": 19191, "ts": 467387933}'
# create_topic-1:0:46: key=None value=b'{"emp_id": "eb5d42f3-b46f-496c-a6e8-ad2bb74d744d", "employee_name": "Paige Watson", "department": "HR", "state": "RJ", "salary": 61368, "age": 39, "bonus": 28921, "ts": 1258129560}'
# create_topic-1:0:47: key=None value=b'{"emp_id": "44937aa0-0175-48ca-b356-f3fb1e0f9a77", "employee_name": "Erica Norris", "department": "IT", "state": "TX", "salary": 54399, "age": 58, "bonus": 28281, "ts": 1365239567}'
# create_topic-1:0:48: key=None value=b'{"emp_id": "f8c299b6-84ce-47ea-b230-dbc38342f953", "employee_name": "Karen Rhodes", "department": "HR", "state": "FL", "salary": 98963, "age": 21, "bonus": 85545, "ts": 174378841}'
# create_topic-1:0:49: key=None value=b'{"emp_id": "eae1d41b-52ae-4efb-b4c6-ce71c27f1f5e", "employee_name": "Patricia Robinson", "department": "IT", "state": "CA", "salary": 16101, "age": 29, "bonus": 5281, "ts": 1254066196}'
# create_topic-1:0:50: key=None value=b'{"emp_id": "6537e2d0-fe28-42e3-ab8d-af7e20209b9a", "employee_name": "Pamela Brown", "department": "IT", "state": "FL", "salary": 128761, "age": 19, "bonus": 2001, "ts": 1222314385}'
# create_topic-1:0:51: key=None value=b'{"emp_id": "32b4d33b-7c73-4e74-b1e0-ea1ffd2f8635", "employee_name": "Elizabeth Brewer", "department": "HR", "state": "NY", "salary": 123752, "age": 23, "bonus": 53019, "ts": 169347311}'
# create_topic-1:0:52: key=None value=b'{"emp_id": "5b850ca1-c28b-4453-a787-c7d51bee69f1", "employee_name": "Steven Andrews", "department": "HR", "state": "IL", "salary": 22777, "age": 44, "bonus": 24694, "ts": 996178489}'
# create_topic-1:0:53: key=None value=b'{"emp_id": "969a5fcd-b4b9-49aa-9115-7d3efd0f5dbf", "employee_name": "Theodore Bell", "department": "Marketing", "state": "FL", "salary": 120632, "age": 40, "bonus": 36794, "ts": 1022525165}'
# create_topic-1:0:54: key=None value=b'{"emp_id": "af351507-7e8d-44f0-9959-a383c7834f17", "employee_name": "Krystal Hernandez", "department": "Marketing", "state": "CA", "salary": 10883, "age": 30, "bonus": 72257, "ts": 235535418}'
# create_topic-1:0:55: key=None value=b'{"emp_id": "e7c5108b-6ec5-4fcb-aa0f-836bc83a88be", "employee_name": "Morgan Davis MD", "department": "IT", "state": "RJ", "salary": 20214, "age": 20, "bonus": 37776, "ts": 1538945994}'
# create_topic-1:0:56: key=None value=b'{"emp_id": "401bf869-a8f9-4e06-8de4-76678fc1d404", "employee_name": "Brenda Rangel", "department": "Marketing", "state": "IL", "salary": 113960, "age": 25, "bonus": 17920, "ts": 1432705369}'
# create_topic-1:0:57: key=None value=b'{"emp_id": "f951baf9-fd2b-4764-ad10-6623fbe651c3", "employee_name": "Amanda Harris", "department": "HR", "state": "NY", "salary": 87718, "age": 29, "bonus": 95561, "ts": 1596601058}'
# create_topic-1:0:58: key=None value=b'{"emp_id": "2cdfc521-4369-4904-8afa-721a57f864c1", "employee_name": "Michael Gonzalez", "department": "Marketing", "state": "TX", "salary": 136859, "age": 57, "bonus": 62042, "ts": 969504874}'
# create_topic-1:0:59: key=None value=b'{"emp_id": "e7cfa6ce-f834-49a1-8980-6b72c3d6095b", "employee_name": "Luke Flowers", "department": "Sales", "state": "RJ", "salary": 43900, "age": 53, "bonus": 27285, "ts": 1160994310}'
# create_topic-1:0:60: key=None value=b'{"emp_id": "6f87d6db-d372-4a07-bb9f-ae5d63a04b23", "employee_name": "Robert Sanchez", "department": "Marketing", "state": "NY", "salary": 10946, "age": 37, "bonus": 77350, "ts": 1421746177}'
# create_topic-1:0:61: key=None value=b'{"emp_id": "eafe94aa-32fc-41d4-9a87-bbd55576f6bf", "employee_name": "Cameron Rodgers", "department": "Marketing", "state": "TX", "salary": 133744, "age": 56, "bonus": 25564, "ts": 1308712262}'
# create_topic-1:0:62: key=None value=b'{"emp_id": "0f10c84e-88f5-4917-9b5d-441d073abf14", "employee_name": "Kayla Richards", "department": "HR", "state": "TX", "salary": 95765, "age": 36, "bonus": 55997, "ts": 328057136}'
# create_topic-1:0:63: key=None value=b'{"emp_id": "b8a51eaa-33cf-4330-b1a9-b77938e22138", "employee_name": "Steven Tucker", "department": "HR", "state": "RJ", "salary": 48598, "age": 22, "bonus": 71962, "ts": 1413637935}'
# create_topic-1:0:64: key=None value=b'{"emp_id": "070481c7-67c2-4ae3-9b96-a9b9f35eb3db", "employee_name": "Yvonne Preston", "department": "IT", "state": "TX", "salary": 62032, "age": 27, "bonus": 71374, "ts": 851338177}'
# create_topic-1:0:65: key=None value=b'{"emp_id": "89dc342e-bbfe-4d26-89fa-c1e8abceafd3", "employee_name": "Brooke Mays", "department": "IT", "state": "NY", "salary": 123618, "age": 26, "bonus": 74613, "ts": 1675172412}'
# create_topic-1:0:66: key=None value=b'{"emp_id": "c98c1811-012b-4092-97fa-7acaa027615f", "employee_name": "Tony Smith", "department": "IT", "state": "IL", "salary": 100711, "age": 46, "bonus": 84489, "ts": 597951658}'
# create_topic-1:0:67: key=None value=b'{"emp_id": "6832cc9b-f013-4ac7-9dc2-41e7c67266b0", "employee_name": "Lisa Saunders", "department": "IT", "state": "TX", "salary": 122527, "age": 19, "bonus": 73190, "ts": 657268140}'
# create_topic-1:0:68: key=None value=b'{"emp_id": "1ebbf620-e487-4f3a-bc32-3a5d37e63870", "employee_name": "Sara Henderson", "department": "IT", "state": "TX", "salary": 105272, "age": 53, "bonus": 46198, "ts": 570360503}'
# create_topic-1:0:69: key=None value=b'{"emp_id": "535c47c9-d10d-457e-9b28-bdc8c92e8757", "employee_name": "Troy Dennis", "department": "IT", "state": "RJ", "salary": 55421, "age": 27, "bonus": 70640, "ts": 449868695}'
# create_topic-1:0:70: key=None value=b'{"emp_id": "b51b8225-405b-476a-bb11-a38b77100bf8", "employee_name": "Rachel Snyder", "department": "HR", "state": "RJ", "salary": 46504, "age": 24, "bonus": 90377, "ts": 1303379129}'
# create_topic-1:0:71: key=None value=b'{"emp_id": "e00d8abf-0502-4499-b33d-ab4671fe3ef7", "employee_name": "Nancy Morrison", "department": "HR", "state": "TX", "salary": 29096, "age": 50, "bonus": 1133, "ts": 1658555962}'
# create_topic-1:0:72: key=None value=b'{"emp_id": "aa5a5834-55ca-4ac9-8066-20e65ae7878e", "employee_name": "Dwayne Wilson", "department": "Marketing", "state": "NY", "salary": 37067, "age": 22, "bonus": 20924, "ts": 1507864506}'
# create_topic-1:0:73: key=None value=b'{"emp_id": "7cb49bda-f6a7-424e-aeee-e42b50bd240c", "employee_name": "Nathan Anderson", "department": "Marketing", "state": "TX", "salary": 67397, "age": 57, "bonus": 90230, "ts": 1592630716}'
# create_topic-1:0:74: key=None value=b'{"emp_id": "772b268f-3d6e-4120-8029-154fcb4dc965", "employee_name": "Derek Nelson", "department": "HR", "state": "NY", "salary": 123710, "age": 49, "bonus": 22995, "ts": 606957299}'
# create_topic-1:0:75: key=None value=b'{"emp_id": "509650f8-5684-49d6-b520-671434d4481a", "employee_name": "Joseph Hardin", "department": "HR", "state": "IL", "salary": 36829, "age": 42, "bonus": 92868, "ts": 1030998833}'
# create_topic-1:0:76: key=None value=b'{"emp_id": "b2cc7ae3-bc37-414c-a35b-0e786dbff502", "employee_name": "David Lewis", "department": "Marketing", "state": "CA", "salary": 117723, "age": 48, "bonus": 67301, "ts": 779656260}'
# create_topic-1:0:77: key=None value=b'{"emp_id": "959c01be-9706-4f73-9afe-462e3ee76b24", "employee_name": "Mackenzie Smith", "department": "Marketing", "state": "NY", "salary": 119581, "age": 31, "bonus": 99275, "ts": 1722656066}'
# create_topic-1:0:78: key=None value=b'{"emp_id": "fdefd579-df32-4ed7-8aec-054bc0fc4cca", "employee_name": "Ann Meadows", "department": "IT", "state": "FL", "salary": 61929, "age": 45, "bonus": 21575, "ts": 852644530}'
# create_topic-1:0:79: key=None value=b'{"emp_id": "012cbdc7-c009-44df-b6a1-c31dbf03d063", "employee_name": "Jeffrey Bullock", "department": "HR", "state": "IL", "salary": 12453, "age": 27, "bonus": 75590, "ts": 1514811962}'
# create_topic-1:0:80: key=None value=b'{"emp_id": "b8bf3c38-3ad8-489c-9f37-9a4f352fe87e", "employee_name": "Keith Carter", "department": "Sales", "state": "NY", "salary": 90066, "age": 33, "bonus": 56722, "ts": 820233630}'
# create_topic-1:0:81: key=None value=b'{"emp_id": "9794f509-ba5c-476a-a803-2b3f93cb7fd9", "employee_name": "Nicholas Oconnor", "department": "Sales", "state": "RJ", "salary": 43270, "age": 37, "bonus": 64438, "ts": 1592717832}'
# create_topic-1:0:82: key=None value=b'{"emp_id": "1ce73bc6-c74b-44aa-940a-07344e00b322", "employee_name": "Edward Rocha", "department": "HR", "state": "NY", "salary": 47416, "age": 33, "bonus": 99922, "ts": 970915045}'
# create_topic-1:0:83: key=None value=b'{"emp_id": "96b39da9-837a-47a0-aa26-3136e87df534", "employee_name": "Michelle Barrera", "department": "Sales", "state": "FL", "salary": 129968, "age": 52, "bonus": 63820, "ts": 1530835441}'
# create_topic-1:0:84: key=None value=b'{"emp_id": "0fbc41c5-90b5-41eb-bf80-9446f3125e45", "employee_name": "Christopher Lang", "department": "Sales", "state": "FL", "salary": 60121, "age": 53, "bonus": 8862, "ts": 373222512}'
# create_topic-1:0:85: key=None value=b'{"emp_id": "67031182-cd36-4344-b635-6ba98e3d0846", "employee_name": "Jason Nixon", "department": "Marketing", "state": "FL", "salary": 149586, "age": 31, "bonus": 30142, "ts": 1331341280}'
# create_topic-1:0:86: key=None value=b'{"emp_id": "e6fd3c6f-ebb1-4c8e-8e71-6889cc9c967c", "employee_name": "Daniel Mueller", "department": "Sales", "state": "TX", "salary": 80686, "age": 18, "bonus": 1850, "ts": 77907422}'
# create_topic-1:0:87: key=None value=b'{"emp_id": "f5e7ec06-0410-4674-96b0-b3208c98c17a", "employee_name": "Ryan Hubbard", "department": "Sales", "state": "NY", "salary": 79509, "age": 54, "bonus": 28176, "ts": 125139105}'
# create_topic-1:0:88: key=None value=b'{"emp_id": "7d832ba5-4e4a-4e80-8405-a0792a9ff805", "employee_name": "Laurie Turner", "department": "Sales", "state": "CA", "salary": 105400, "age": 38, "bonus": 75782, "ts": 656792051}'
# create_topic-1:0:89: key=None value=b'{"emp_id": "b1d2d670-4233-4b6c-b3cd-5844553d18c9", "employee_name": "Carlos Becker", "department": "HR", "state": "FL", "salary": 42779, "age": 25, "bonus": 28588, "ts": 1422296710}'
# create_topic-1:0:90: key=None value=b'{"emp_id": "638a93fa-2598-4152-a8cf-e1ac4377c14a", "employee_name": "Meghan Campbell", "department": "Marketing", "state": "TX", "salary": 60150, "age": 44, "bonus": 37284, "ts": 680750727}'
# create_topic-1:0:91: key=None value=b'{"emp_id": "713bf307-26e9-49c4-8649-0fdfa2d6358c", "employee_name": "Sandra Wood", "department": "HR", "state": "TX", "salary": 101297, "age": 46, "bonus": 86167, "ts": 1059438577}'
# create_topic-1:0:92: key=None value=b'{"emp_id": "515e8612-1b41-48a3-a00a-0587e4678c6f", "employee_name": "Nancy Long", "department": "IT", "state": "FL", "salary": 71445, "age": 23, "bonus": 76315, "ts": 1107164922}'
# create_topic-1:0:93: key=None value=b'{"emp_id": "cac83644-a1ed-4bf2-a89b-989a903e46b4", "employee_name": "Mike Burns", "department": "IT", "state": "NY", "salary": 98865, "age": 26, "bonus": 60029, "ts": 1358424803}'
# create_topic-1:0:94: key=None value=b'{"emp_id": "da8e675b-e5cd-4560-8627-5c8d6359136a", "employee_name": "Raymond Lewis", "department": "Marketing", "state": "RJ", "salary": 92541, "age": 35, "bonus": 53313, "ts": 1543162136}'
# create_topic-1:0:95: key=None value=b'{"emp_id": "bf9838e6-50e7-4675-9d17-9271e91f89e8", "employee_name": "Marisa Galvan", "department": "Sales", "state": "IL", "salary": 13874, "age": 60, "bonus": 26619, "ts": 595014733}'
# create_topic-1:0:96: key=None value=b'{"emp_id": "91138dca-fe5a-4907-885c-ff292b158e14", "employee_name": "Mr. Richard Warner", "department": "Sales", "state": "TX", "salary": 66444, "age": 56, "bonus": 2480, "ts": 1179117153}'
# create_topic-1:0:97: key=None value=b'{"emp_id": "63756c81-5b58-4bb6-b1b6-3a212590c908", "employee_name": "Angela Walker", "department": "HR", "state": "TX", "salary": 118998, "age": 54, "bonus": 18385, "ts": 870774303}'
# create_topic-1:0:98: key=None value=b'{"emp_id": "b2825b64-4a78-4f07-93fc-466ef6a37bcc", "employee_name": "Andrea Goodman", "department": "Marketing", "state": "FL", "salary": 146676, "age": 35, "bonus": 93673, "ts": 720974999}'
# create_topic-1:0:99: key=None value=b'{"emp_id": "7aa6b012-b896-4df5-9deb-db734fc22114", "employee_name": "Linda Tanner", "department": "HR", "state": "RJ", "salary": 141361, "age": 44, "bonus": 34825, "ts": 1304177389}'
# create_topic-1:0:100: key=None value=b'{"emp_id": "86d369ed-dc8b-4c66-b911-96ca5e05078f", "employee_name": "Kimberly Gray", "department": "Marketing", "state": "RJ", "salary": 55568, "age": 38, "bonus": 88171, "ts": 1666292428}'
# create_topic-1:0:101: key=None value=b'{"emp_id": "2b34ddfa-9a92-4f44-a482-cbdbf4cbdea5", "employee_name": "Danielle Stanton", "department": "HR", "state": "IL", "salary": 40715, "age": 41, "bonus": 72664, "ts": 813512803}'
# create_topic-1:0:102: key=None value=b'{"emp_id": "3ecca87a-edab-478f-988e-125c1ac23efc", "employee_name": "Jason Shaw", "department": "Marketing", "state": "TX", "salary": 17036, "age": 30, "bonus": 12747, "ts": 671938162}'
# create_topic-1:0:103: key=None value=b'{"emp_id": "d3c5e68c-0217-453f-b230-53a8ed081b89", "employee_name": "Latoya Gordon", "department": "Sales", "state": "CA", "salary": 124291, "age": 56, "bonus": 94653, "ts": 734940793}'
# create_topic-1:0:104: key=None value=b'{"emp_id": "32de341d-78ec-47ea-9896-38331367e0a1", "employee_name": "Daniel Cooper", "department": "IT", "state": "FL", "salary": 124127, "age": 60, "bonus": 40055, "ts": 1577354064}'
# create_topic-1:0:105: key=None value=b'{"emp_id": "654ecb35-b58c-48b8-9ad6-adc61ac3e79f", "employee_name": "Sara Smith", "department": "Marketing", "state": "CA", "salary": 54196, "age": 20, "bonus": 95204, "ts": 1560343693}'
# create_topic-1:0:106: key=None value=b'{"emp_id": "5310ae59-1a33-48cf-ae9b-c0417f3bd2d6", "employee_name": "Amber Greene", "department": "Marketing", "state": "RJ", "salary": 58816, "age": 41, "bonus": 76665, "ts": 591917376}'
# create_topic-1:0:107: key=None value=b'{"emp_id": "e9ac7fe4-b096-46aa-b650-eae09704d0d0", "employee_name": "Monica Marquez", "department": "Marketing", "state": "IL", "salary": 114339, "age": 54, "bonus": 25294, "ts": 1248128428}'
# create_topic-1:0:108: key=None value=b'{"emp_id": "0ca10ef8-8ca7-484e-80c6-43fdbe2cfcb9", "employee_name": "Leslie Mcmillan", "department": "Sales", "state": "FL", "salary": 86216, "age": 41, "bonus": 50912, "ts": 843569713}'
# create_topic-1:0:109: key=None value=b'{"emp_id": "dbbd54ce-f54a-4846-a547-81f96ae3d102", "employee_name": "Nicole Allen", "department": "Sales", "state": "TX", "salary": 97105, "age": 21, "bonus": 28800, "ts": 1132706561}'
# create_topic-1:0:110: key=None value=b'{"emp_id": "db812cdc-13b9-44f8-a776-bb2a2834af65", "employee_name": "Joel Dean", "department": "Marketing", "state": "FL", "salary": 71765, "age": 24, "bonus": 54279, "ts": 622507411}'
# create_topic-1:0:111: key=None value=b'{"emp_id": "71b3fc39-6eb7-4ab5-beea-bc76b02e519d", "employee_name": "Dale Saunders", "department": "Sales", "state": "TX", "salary": 107741, "age": 19, "bonus": 85987, "ts": 941178683}'
# create_topic-1:0:112: key=None value=b'{"emp_id": "39a03c0a-ccf2-4efd-b3a5-b39d97761ceb", "employee_name": "Michael Henderson", "department": "Sales", "state": "IL", "salary": 46049, "age": 59, "bonus": 19721, "ts": 1420427737}'
# create_topic-1:0:113: key=None value=b'{"emp_id": "6ec18a08-c86e-4d60-9921-ab87ea4048c1", "employee_name": "Sue Peterson", "department": "Sales", "state": "CA", "salary": 77867, "age": 41, "bonus": 82948, "ts": 1543544314}'
# create_topic-1:0:114: key=None value=b'{"emp_id": "05ba85be-0798-4d52-8292-f7ae744c58a6", "employee_name": "Kenneth Cruz", "department": "Sales", "state": "NY", "salary": 56452, "age": 22, "bonus": 88942, "ts": 634940030}'
# create_topic-1:0:115: key=None value=b'{"emp_id": "8a5dd214-681a-417e-b5b0-2238292cfb26", "employee_name": "Casey Roth", "department": "HR", "state": "TX", "salary": 111636, "age": 52, "bonus": 51084, "ts": 152829963}'
# create_topic-1:0:116: key=None value=b'{"emp_id": "c9355aec-163e-4723-8e3b-812af25885f7", "employee_name": "Kim Nichols", "department": "IT", "state": "IL", "salary": 60311, "age": 40, "bonus": 5396, "ts": 1129466263}'
# create_topic-1:0:117: key=None value=b'{"emp_id": "1faa6a44-a176-40b9-827d-c70f3eda8267", "employee_name": "Steve James", "department": "IT", "state": "RJ", "salary": 138953, "age": 23, "bonus": 53147, "ts": 189540017}'
# create_topic-1:0:118: key=None value=b'{"emp_id": "d33fb0ee-8505-47af-b7ce-18ea900e381c", "employee_name": "Elizabeth Patterson", "department": "IT", "state": "NY", "salary": 98000, "age": 22, "bonus": 70474, "ts": 1103508903}'
# create_topic-1:0:119: key=None value=b'{"emp_id": "2c74e951-86cd-4464-ba3b-bdde77aee791", "employee_name": "Sara Frost", "department": "Sales", "state": "FL", "salary": 110427, "age": 33, "bonus": 80459, "ts": 196336851}'
# create_topic-1:0:120: key=None value=b'{"emp_id": "d356fa3a-0a7c-48d6-b97f-f25c218ec423", "employee_name": "Jon Elliott", "department": "IT", "state": "FL", "salary": 38176, "age": 48, "bonus": 14650, "ts": 472116759}'
# create_topic-1:0:121: key=None value=b'{"emp_id": "ae500776-58da-45a8-b94e-22dd87a883bd", "employee_name": "Jason Cameron", "department": "IT", "state": "NY", "salary": 95199, "age": 39, "bonus": 36821, "ts": 1347124449}'
# create_topic-1:0:122: key=None value=b'{"emp_id": "9f3dff2a-2059-44b0-905e-f471a2d6c425", "employee_name": "Jerry Hamilton", "department": "HR", "state": "NY", "salary": 117352, "age": 54, "bonus": 3630, "ts": 1400597121}'
# create_topic-1:0:123: key=None value=b'{"emp_id": "d32c24b9-74b3-4d3f-95cf-6afd81bd6520", "employee_name": "Kimberly Williams", "department": "Sales", "state": "CA", "salary": 135331, "age": 29, "bonus": 44860, "ts": 44785012}'
# create_topic-1:0:124: key=None value=b'{"emp_id": "9b77988b-8695-46cb-9c66-98251364de63", "employee_name": "Brenda Mueller", "department": "IT", "state": "NY", "salary": 112117, "age": 50, "bonus": 47007, "ts": 1089963457}'
# create_topic-1:0:125: key=None value=b'{"emp_id": "f2790f4f-12e8-435d-9b6e-049f6128acd1", "employee_name": "Charles Thompson", "department": "Marketing", "state": "CA", "salary": 57755, "age": 56, "bonus": 93502, "ts": 602317171}'
# create_topic-1:0:126: key=None value=b'{"emp_id": "0d693ab7-487f-4444-8003-533256d962aa", "employee_name": "Larry King", "department": "HR", "state": "FL", "salary": 115008, "age": 39, "bonus": 60629, "ts": 320893532}'
# create_topic-1:0:127: key=None value=b'{"emp_id": "1f1090c8-7842-436a-8d85-72b451d5591e", "employee_name": "Lonnie King", "department": "HR", "state": "NY", "salary": 51872, "age": 38, "bonus": 56429, "ts": 1257222112}'
# create_topic-1:0:128: key=None value=b'{"emp_id": "b6fe03ef-9b74-460e-a13f-2f5b5b04b7ea", "employee_name": "Monica Wilson", "department": "Marketing", "state": "CA", "salary": 109444, "age": 44, "bonus": 55237, "ts": 708827215}'
# create_topic-1:0:129: key=None value=b'{"emp_id": "9fc8a60f-7033-4d49-99fd-41f5339c3c35", "employee_name": "Alejandro Mcdowell", "department": "IT", "state": "RJ", "salary": 36992, "age": 23, "bonus": 35197, "ts": 1628927288}'
# create_topic-1:0:130: key=None value=b'{"emp_id": "626cd43f-1290-4356-a1f5-2c1777b65f88", "employee_name": "Isaac Green", "department": "Marketing", "state": "CA", "salary": 20664, "age": 32, "bonus": 56115, "ts": 161422519}'
# create_topic-1:0:131: key=None value=b'{"emp_id": "2144840a-58b3-44e6-a640-3c4ad008e2fb", "employee_name": "Curtis Marshall", "department": "Marketing", "state": "NY", "salary": 105932, "age": 34, "bonus": 9747, "ts": 958283707}'
# create_topic-1:0:132: key=None value=b'{"emp_id": "5b5504d3-042e-41ef-b4de-0a4c358522ba", "employee_name": "Brandy Bell", "department": "HR", "state": "FL", "salary": 74868, "age": 53, "bonus": 65018, "ts": 639170784}'
# create_topic-1:0:133: key=None value=b'{"emp_id": "6bf2eb33-ce68-4d39-a314-52dc9bcc2e16", "employee_name": "Tracey Roberts", "department": "HR", "state": "FL", "salary": 125119, "age": 33, "bonus": 96951, "ts": 1455604749}'
# create_topic-1:0:134: key=None value=b'{"emp_id": "9093e55b-7ee6-4c32-a2db-55862b5c1866", "employee_name": "Angel Logan", "department": "Sales", "state": "NY", "salary": 31144, "age": 52, "bonus": 23275, "ts": 95677923}'
# create_topic-1:0:135: key=None value=b'{"emp_id": "1d1057e5-3a55-407d-b9d5-03b331a0137e", "employee_name": "Jerry Alexander", "department": "HR", "state": "RJ", "salary": 14286, "age": 27, "bonus": 89301, "ts": 397411741}'
# create_topic-1:0:136: key=None value=b'{"emp_id": "e552f488-1238-4525-bd99-09f0c9530323", "employee_name": "Deborah Perez", "department": "IT", "state": "FL", "salary": 102965, "age": 29, "bonus": 88105, "ts": 1664528270}'
# create_topic-1:0:137: key=None value=b'{"emp_id": "53669587-0b1d-4470-8f31-1c072d11894a", "employee_name": "David Sawyer", "department": "HR", "state": "FL", "salary": 70186, "age": 46, "bonus": 9893, "ts": 1608659377}'
# create_topic-1:0:138: key=None value=b'{"emp_id": "3f37d00b-7a6b-4cb8-b45c-128de1d6c0c8", "employee_name": "Katherine Phillips", "department": "HR", "state": "CA", "salary": 87579, "age": 37, "bonus": 41869, "ts": 782604068}'
# create_topic-1:0:139: key=None value=b'{"emp_id": "02fa76b9-f0fa-4496-b74a-2533143380e3", "employee_name": "Charles Larsen", "department": "HR", "state": "TX", "salary": 125457, "age": 26, "bonus": 56385, "ts": 179351193}'
# create_topic-1:0:140: key=None value=b'{"emp_id": "56d115fc-63ec-4e0e-b01c-56c573e4ed55", "employee_name": "Ryan Taylor", "department": "IT", "state": "CA", "salary": 77127, "age": 28, "bonus": 18883, "ts": 1121614873}'
# create_topic-1:0:141: key=None value=b'{"emp_id": "1152ad44-5b8e-4983-838d-b3540b874f30", "employee_name": "Stacey Brown", "department": "Marketing", "state": "NY", "salary": 15896, "age": 24, "bonus": 98637, "ts": 230172711}'
# create_topic-1:0:142: key=None value=b'{"emp_id": "7b1a22d4-e5b3-44d3-b616-d4aff384b4e4", "employee_name": "Susan Hayes", "department": "HR", "state": "FL", "salary": 89152, "age": 56, "bonus": 6346, "ts": 1087934536}'
# create_topic-1:0:143: key=None value=b'{"emp_id": "0b7981a5-ed12-40d8-9814-6b67e1d46832", "employee_name": "Kristine Smith", "department": "HR", "state": "RJ", "salary": 104985, "age": 43, "bonus": 28066, "ts": 794166086}'
# create_topic-1:0:144: key=None value=b'{"emp_id": "2ad8a295-6332-4385-a603-ff7f55a8df15", "employee_name": "Erica Torres", "department": "HR", "state": "TX", "salary": 71084, "age": 43, "bonus": 66244, "ts": 893791705}'
# create_topic-1:0:145: key=None value=b'{"emp_id": "fd5786bd-3b85-43da-8cea-030c7c55c29d", "employee_name": "Ashley Guerrero", "department": "Sales", "state": "RJ", "salary": 58360, "age": 46, "bonus": 91760, "ts": 1247691275}'
# create_topic-1:0:146: key=None value=b'{"emp_id": "fa153ace-43c0-4e72-abd1-1c54fd09ff7a", "employee_name": "Ann Jordan", "department": "Sales", "state": "NY", "salary": 95119, "age": 48, "bonus": 4492, "ts": 584392749}'
# create_topic-1:0:147: key=None value=b'{"emp_id": "4a38d504-9b08-482b-a8e1-5d7dc1796546", "employee_name": "James Black", "department": "IT", "state": "NY", "salary": 15445, "age": 26, "bonus": 73779, "ts": 761487515}'
# create_topic-1:0:148: key=None value=b'{"emp_id": "8f1be0d9-1b22-48bc-b41e-dc4e06ecd511", "employee_name": "Chris Solis", "department": "IT", "state": "FL", "salary": 30275, "age": 59, "bonus": 74746, "ts": 1696683537}'
# create_topic-1:0:149: key=None value=b'{"emp_id": "6d4f13fe-e1a5-4efc-9b24-071720ef13a0", "employee_name": "Christopher Knight", "department": "IT", "state": "RJ", "salary": 113811, "age": 57, "bonus": 74630, "ts": 764236932}'
# create_topic-1:0:150: key=None value=b'{"emp_id": "ba1dd94e-48da-4b29-9d9f-a237fd2380dd", "employee_name": "Dawn Irwin", "department": "IT", "state": "NY", "salary": 73336, "age": 38, "bonus": 45707, "ts": 324660166}'
# create_topic-1:0:151: key=None value=b'{"emp_id": "4b8dcaca-95ef-4b2d-8bd7-2d3f947f9331", "employee_name": "Deborah Day", "department": "Marketing", "state": "TX", "salary": 50720, "age": 26, "bonus": 66090, "ts": 715395706}'
# create_topic-1:0:152: key=None value=b'{"emp_id": "798327d3-9a22-4bdd-8503-d3047b2f1875", "employee_name": "Lisa Macdonald", "department": "HR", "state": "RJ", "salary": 46591, "age": 28, "bonus": 38475, "ts": 609798816}'
# create_topic-1:0:153: key=None value=b'{"emp_id": "23b39d3c-4ee3-48d9-971a-dc3dce0b4707", "employee_name": "Jessica Jenkins", "department": "IT", "state": "CA", "salary": 104780, "age": 27, "bonus": 63919, "ts": 899693126}'
# create_topic-1:0:154: key=None value=b'{"emp_id": "d8ad0e0f-b478-4733-8888-7ec797e2cb98", "employee_name": "Crystal Gray", "department": "Marketing", "state": "FL", "salary": 24032, "age": 52, "bonus": 45785, "ts": 554959344}'
# create_topic-1:0:155: key=None value=b'{"emp_id": "66f4da07-a37a-4f1d-9e21-b1b566ad6da9", "employee_name": "Christopher Wright", "department": "HR", "state": "NY", "salary": 84835, "age": 46, "bonus": 96805, "ts": 158765174}'
# create_topic-1:0:156: key=None value=b'{"emp_id": "59ea3fed-61e8-4873-9b59-e6395ccb9f8e", "employee_name": "Jason Joseph", "department": "Marketing", "state": "NY", "salary": 80176, "age": 18, "bonus": 10889, "ts": 1020232944}'
# create_topic-1:0:157: key=None value=b'{"emp_id": "52c42a34-949a-44e0-a550-94b15b78c850", "employee_name": "Edward Norton", "department": "Sales", "state": "CA", "salary": 14168, "age": 60, "bonus": 91924, "ts": 563671250}'
# create_topic-1:0:158: key=None value=b'{"emp_id": "2ef57aa4-4cda-437c-8d0a-a458592e58bb", "employee_name": "Tammy Sandoval", "department": "Sales", "state": "IL", "salary": 13021, "age": 33, "bonus": 44784, "ts": 1543705583}'
# create_topic-1:0:159: key=None value=b'{"emp_id": "7fda2881-dfdc-455d-8f53-c0e1cf659e6e", "employee_name": "Nichole Swanson", "department": "Sales", "state": "FL", "salary": 136462, "age": 59, "bonus": 80499, "ts": 961373745}'
# create_topic-1:0:160: key=None value=b'{"emp_id": "a9dcf879-4f3e-4ab8-8e45-1f6f54ff917a", "employee_name": "Lindsay White", "department": "Sales", "state": "IL", "salary": 33594, "age": 26, "bonus": 46317, "ts": 515840483}'
# create_topic-1:0:161: key=None value=b'{"emp_id": "bc0b67f5-ebe2-4135-8feb-f4c7aa030d6f", "employee_name": "Rhonda Austin", "department": "Sales", "state": "NY", "salary": 141659, "age": 30, "bonus": 71172, "ts": 1595144244}'
# create_topic-1:0:162: key=None value=b'{"emp_id": "6879ff91-650d-48c9-9b84-3f80780c13fb", "employee_name": "Catherine Mccann", "department": "Sales", "state": "IL", "salary": 75351, "age": 32, "bonus": 39572, "ts": 1207367575}'
# create_topic-1:0:163: key=None value=b'{"emp_id": "b5a76820-2e76-4796-bea5-40c9669f4403", "employee_name": "Gina Valdez", "department": "Sales", "state": "NY", "salary": 97292, "age": 23, "bonus": 26308, "ts": 1385984631}'
# create_topic-1:0:164: key=None value=b'{"emp_id": "20ff3b09-c269-4cd4-8688-79587844ce30", "employee_name": "Lisa Williams", "department": "HR", "state": "IL", "salary": 51794, "age": 35, "bonus": 51868, "ts": 1022626134}'
# create_topic-1:0:165: key=None value=b'{"emp_id": "d3b7681d-406c-4182-b628-bcb5afb5e29a", "employee_name": "Terry Ayala", "department": "HR", "state": "CA", "salary": 94732, "age": 58, "bonus": 4367, "ts": 1473896454}'
# create_topic-1:0:166: key=None value=b'{"emp_id": "0b9077c6-df0d-4811-aaeb-79cb26e3077c", "employee_name": "Michael Brown", "department": "IT", "state": "IL", "salary": 20893, "age": 40, "bonus": 54057, "ts": 1711589926}'
# create_topic-1:0:167: key=None value=b'{"emp_id": "4e6364b5-2a9f-4b58-b4b7-91ab73458d59", "employee_name": "Hunter Boyd", "department": "HR", "state": "CA", "salary": 126714, "age": 29, "bonus": 31785, "ts": 319055628}'
# create_topic-1:0:168: key=None value=b'{"emp_id": "02864283-bad9-43b1-a8f0-c5ecfdb03e8a", "employee_name": "Lisa Allen", "department": "HR", "state": "TX", "salary": 102167, "age": 59, "bonus": 62480, "ts": 1422968948}'
# create_topic-1:0:169: key=None value=b'{"emp_id": "9055ce85-7fed-4626-a80a-68fec2136f40", "employee_name": "Matthew Simmons", "department": "HR", "state": "RJ", "salary": 21296, "age": 47, "bonus": 1823, "ts": 744734017}'
# create_topic-1:0:170: key=None value=b'{"emp_id": "c0ce1011-62aa-49fd-bb9d-01d1efd076f8", "employee_name": "Troy George", "department": "HR", "state": "CA", "salary": 87386, "age": 40, "bonus": 27213, "ts": 275379214}'
# create_topic-1:0:171: key=None value=b'{"emp_id": "a0aff3c7-922e-4850-b102-cf75123e0382", "employee_name": "Timothy Lane", "department": "HR", "state": "RJ", "salary": 140358, "age": 26, "bonus": 20269, "ts": 872839256}'
# create_topic-1:0:172: key=None value=b'{"emp_id": "5f6ee6d7-62a7-4d63-b44d-8d5dbaa8c164", "employee_name": "Steven Knight", "department": "IT", "state": "CA", "salary": 24868, "age": 40, "bonus": 3270, "ts": 957551030}'
# create_topic-1:0:173: key=None value=b'{"emp_id": "8af23ebc-f070-48ad-b16f-5ba1ebf86677", "employee_name": "Sabrina Macdonald", "department": "Marketing", "state": "FL", "salary": 51673, "age": 29, "bonus": 23495, "ts": 841360243}'
# create_topic-1:0:174: key=None value=b'{"emp_id": "b2243d37-9056-4c4f-844b-342b7521a4ad", "employee_name": "Christopher Reynolds", "department": "Sales", "state": "NY", "salary": 18266, "age": 52, "bonus": 34936, "ts": 280547941}'
# create_topic-1:0:175: key=None value=b'{"emp_id": "99469669-0c6f-426a-9f40-51398335de35", "employee_name": "Lydia Randall", "department": "Marketing", "state": "RJ", "salary": 144509, "age": 43, "bonus": 57690, "ts": 1429183943}'
# create_topic-1:0:176: key=None value=b'{"emp_id": "04b40966-7c90-46a5-995a-7d22fd308388", "employee_name": "Walter Armstrong", "department": "IT", "state": "IL", "salary": 28485, "age": 23, "bonus": 99383, "ts": 172070253}'
# create_topic-1:0:177: key=None value=b'{"emp_id": "b9790761-2640-4459-9e4a-a13479ed674a", "employee_name": "Maria Fitzpatrick", "department": "Sales", "state": "FL", "salary": 38573, "age": 50, "bonus": 53584, "ts": 1253380856}'
# create_topic-1:0:178: key=None value=b'{"emp_id": "06279f03-ed64-43f9-8e16-b4606341e56f", "employee_name": "Danielle Nunez", "department": "Marketing", "state": "CA", "salary": 110865, "age": 39, "bonus": 31573, "ts": 1675967299}'
# create_topic-1:0:179: key=None value=b'{"emp_id": "f54a771b-9180-4d7d-a0a8-d2ec62ca7154", "employee_name": "Jessica Cooper", "department": "Marketing", "state": "TX", "salary": 109936, "age": 43, "bonus": 8762, "ts": 1317091049}'
# create_topic-1:0:180: key=None value=b'{"emp_id": "468e10ec-887d-44e7-985e-e6e2bf6b133b", "employee_name": "Christine Martinez", "department": "Sales", "state": "TX", "salary": 94112, "age": 41, "bonus": 42242, "ts": 1531587883}'
# create_topic-1:0:181: key=None value=b'{"emp_id": "23dbec0c-94ef-4f4e-986b-bc0e86a96bb1", "employee_name": "Christopher Wright", "department": "HR", "state": "NY", "salary": 87382, "age": 48, "bonus": 13147, "ts": 1055712676}'
# create_topic-1:0:182: key=None value=b'{"emp_id": "1f748fc6-a971-4802-b5ef-389ac5f4e217", "employee_name": "Brooke Anderson", "department": "Sales", "state": "RJ", "salary": 81809, "age": 28, "bonus": 13590, "ts": 315036940}'
# create_topic-1:0:183: key=None value=b'{"emp_id": "9581512a-c8ec-4e92-8cb1-603a48a49689", "employee_name": "Ashley Lynch", "department": "HR", "state": "IL", "salary": 138658, "age": 38, "bonus": 99507, "ts": 1622526764}'
# create_topic-1:0:184: key=None value=b'{"emp_id": "c7738fc8-537a-4c63-8461-1ddb7ec7e442", "employee_name": "Chase Long", "department": "IT", "state": "RJ", "salary": 65921, "age": 26, "bonus": 73431, "ts": 1735573124}'
# create_topic-1:0:185: key=None value=b'{"emp_id": "b6b735db-6693-4450-8eb0-e3a6cbd3c2b4", "employee_name": "Kathleen Stephens", "department": "IT", "state": "RJ", "salary": 39863, "age": 55, "bonus": 13936, "ts": 1116677887}'
# create_topic-1:0:186: key=None value=b'{"emp_id": "0158b50e-080f-433f-84ff-e2d89649d69b", "employee_name": "Jennifer Graham", "department": "Marketing", "state": "CA", "salary": 76619, "age": 53, "bonus": 83150, "ts": 172442527}'
# create_topic-1:0:187: key=None value=b'{"emp_id": "381370bb-958f-4caf-a749-a36e390f1a1b", "employee_name": "Sherri Cruz", "department": "HR", "state": "TX", "salary": 16906, "age": 55, "bonus": 52109, "ts": 1054844794}'
# create_topic-1:0:188: key=None value=b'{"emp_id": "0442fa0b-6d47-4c33-adcc-982ae975d75c", "employee_name": "Daniel Collier", "department": "IT", "state": "RJ", "salary": 47639, "age": 27, "bonus": 68663, "ts": 435564815}'
# create_topic-1:0:189: key=None value=b'{"emp_id": "642a6c90-865f-418e-bd63-fd72a24f9b43", "employee_name": "Shelley Gilmore", "department": "IT", "state": "NY", "salary": 38921, "age": 58, "bonus": 53563, "ts": 504525622}'
# create_topic-1:0:190: key=None value=b'{"emp_id": "6d59dd55-6ef6-4656-a480-ea76ad791d59", "employee_name": "Ricardo Herman", "department": "Marketing", "state": "IL", "salary": 110616, "age": 51, "bonus": 27285, "ts": 1335252397}'
# create_topic-1:0:191: key=None value=b'{"emp_id": "d14fa674-222e-4885-8c70-dc8e53c4cc0e", "employee_name": "Tina Waters", "department": "IT", "state": "TX", "salary": 10834, "age": 27, "bonus": 4160, "ts": 874727583}'
# create_topic-1:0:192: key=None value=b'{"emp_id": "7b72b8fd-c7ee-44da-864e-eac87364f820", "employee_name": "Cynthia Greene", "department": "Sales", "state": "FL", "salary": 123119, "age": 37, "bonus": 14792, "ts": 522922681}'
# create_topic-1:0:193: key=None value=b'{"emp_id": "4a343e31-7914-4ac6-aaf8-85d4d9b29174", "employee_name": "Kristin Francis", "department": "IT", "state": "RJ", "salary": 93284, "age": 22, "bonus": 79594, "ts": 1283697448}'
# create_topic-1:0:194: key=None value=b'{"emp_id": "10c7934e-6778-4d4d-baf7-51facf9ce852", "employee_name": "Sandra Whitaker", "department": "IT", "state": "RJ", "salary": 59827, "age": 50, "bonus": 28067, "ts": 1182814141}'
# create_topic-1:0:195: key=None value=b'{"emp_id": "9fbacfe2-b274-4969-8af5-47587f851f7d", "employee_name": "Cassandra Soto", "department": "HR", "state": "NY", "salary": 28875, "age": 25, "bonus": 30432, "ts": 111599839}'
# create_topic-1:0:196: key=None value=b'{"emp_id": "490327e6-fa8b-4042-be3b-5cb76b8a5453", "employee_name": "Vanessa Smith", "department": "Marketing", "state": "CA", "salary": 88717, "age": 38, "bonus": 79808, "ts": 819543283}'
# create_topic-1:0:197: key=None value=b'{"emp_id": "bc8741a2-9a37-4a12-be94-7cafd63717e3", "employee_name": "Matthew Anderson", "department": "IT", "state": "FL", "salary": 22052, "age": 55, "bonus": 34899, "ts": 857225031}'
# create_topic-1:0:198: key=None value=b'{"emp_id": "d47e6b78-e059-4ec6-8a54-3ad9705ac3bc", "employee_name": "Robert Macias", "department": "IT", "state": "NY", "salary": 118836, "age": 56, "bonus": 98553, "ts": 420007761}'
# create_topic-1:0:199: key=None value=b'{"emp_id": "6e151554-598e-4209-bd38-b3ca3278a901", "employee_name": "Lucas Henry", "department": "HR", "state": "NY", "salary": 27341, "age": 19, "bonus": 22862, "ts": 1304825120}'
# create_topic-1:0:200: key=None value=b'{"emp_id": "c91ea1af-9b94-46d6-90be-b8762f6a2f38", "employee_name": "Mark Adams", "department": "Sales", "state": "IL", "salary": 17487, "age": 59, "bonus": 38299, "ts": 1446160306}'
# create_topic-1:0:201: key=None value=b'{"emp_id": "011e7630-6d11-43cc-b6f1-52917608de48", "employee_name": "Sarah Proctor", "department": "Sales", "state": "FL", "salary": 76100, "age": 45, "bonus": 67116, "ts": 185398993}'
# create_topic-1:0:202: key=None value=b'{"emp_id": "fb3ffae1-2880-49fb-a9b6-b7ed7f3a7784", "employee_name": "Anita Kennedy", "department": "HR", "state": "CA", "salary": 124597, "age": 23, "bonus": 47292, "ts": 215004393}'
# create_topic-1:0:203: key=None value=b'{"emp_id": "b3903605-eb29-4b04-96f5-a7bbd4e1fe33", "employee_name": "Michael Rhodes", "department": "HR", "state": "IL", "salary": 120167, "age": 39, "bonus": 14965, "ts": 1204347855}'
# create_topic-1:0:204: key=None value=b'{"emp_id": "62356c8b-9519-4689-8f44-ab87c3a55c59", "employee_name": "Angela Anderson", "department": "Sales", "state": "RJ", "salary": 139878, "age": 34, "bonus": 53506, "ts": 1419256996}'
# create_topic-1:0:205: key=None value=b'{"emp_id": "bf9f911c-fc66-4401-8546-332c1fefe619", "employee_name": "Michael Brown", "department": "IT", "state": "IL", "salary": 65361, "age": 45, "bonus": 2779, "ts": 169971836}'
# create_topic-1:0:206: key=None value=b'{"emp_id": "67749fef-330a-4dc5-88ab-d44ea941e2a6", "employee_name": "Jill Hunter", "department": "HR", "state": "TX", "salary": 103502, "age": 24, "bonus": 58080, "ts": 1177079281}'
# create_topic-1:0:207: key=None value=b'{"emp_id": "ff969ad0-a5f6-4296-8672-023eeab1272e", "employee_name": "Ashley Copeland", "department": "IT", "state": "CA", "salary": 145067, "age": 57, "bonus": 55053, "ts": 103926914}'
# create_topic-1:0:208: key=None value=b'{"emp_id": "abea3ba7-0cc1-4ba2-ac66-b32de26199ca", "employee_name": "Christopher Wilson", "department": "Marketing", "state": "TX", "salary": 15865, "age": 44, "bonus": 8042, "ts": 1045642164}'
# create_topic-1:0:209: key=None value=b'{"emp_id": "66fc1b60-2b81-4616-ae99-c16b2cd39b56", "employee_name": "Karen Saunders", "department": "IT", "state": "FL", "salary": 123380, "age": 36, "bonus": 73050, "ts": 887053543}'
# create_topic-1:0:210: key=None value=b'{"emp_id": "0f1fcbba-9157-4022-bdbf-2033243b982d", "employee_name": "Julie Pollard MD", "department": "HR", "state": "TX", "salary": 71014, "age": 23, "bonus": 96090, "ts": 1116105819}'
# create_topic-1:0:211: key=None value=b'{"emp_id": "f8e1bf8c-ebd1-4837-8d91-056e1f42f5c4", "employee_name": "Lori Roman", "department": "Sales", "state": "NY", "salary": 111418, "age": 60, "bonus": 78624, "ts": 413865422}'
# create_topic-1:0:212: key=None value=b'{"emp_id": "5dc151dd-8836-4b94-8acf-6c37cf5095dd", "employee_name": "Nicholas Hart", "department": "IT", "state": "TX", "salary": 11310, "age": 52, "bonus": 50062, "ts": 757474473}'
# create_topic-1:0:213: key=None value=b'{"emp_id": "8f88d616-e2e1-4784-9b20-6d4553d5d28c", "employee_name": "Jaime Perez", "department": "HR", "state": "NY", "salary": 47374, "age": 25, "bonus": 71721, "ts": 235363572}'
# create_topic-1:0:214: key=None value=b'{"emp_id": "ee67d989-e2aa-4dc9-80cb-2007b2320570", "employee_name": "Brian Maxwell", "department": "HR", "state": "CA", "salary": 125963, "age": 47, "bonus": 21882, "ts": 1672905039}'
# create_topic-1:0:215: key=None value=b'{"emp_id": "0a7cece8-0d9b-44e0-93e3-e7c4baa682ee", "employee_name": "Sara Nash", "department": "Sales", "state": "IL", "salary": 138852, "age": 26, "bonus": 18966, "ts": 398950727}'
# create_topic-1:0:216: key=None value=b'{"emp_id": "67dbd672-e7da-49b7-b53b-92668b2c12d8", "employee_name": "Joshua Gibson", "department": "Sales", "state": "TX", "salary": 104223, "age": 33, "bonus": 90422, "ts": 1256816967}'
# create_topic-1:0:217: key=None value=b'{"emp_id": "1786df2f-7cfb-4a15-880b-dda7dec2a32c", "employee_name": "Jennifer Taylor", "department": "HR", "state": "FL", "salary": 119549, "age": 49, "bonus": 68632, "ts": 739358084}'
# create_topic-1:0:218: key=None value=b'{"emp_id": "566faa5d-d69b-4cef-bbb5-759be072a698", "employee_name": "Kaylee Ferguson", "department": "Sales", "state": "CA", "salary": 138653, "age": 31, "bonus": 82731, "ts": 339701909}'
# create_topic-1:0:219: key=None value=b'{"emp_id": "520ebe8a-0e34-4b33-a954-fb1b85fccc5f", "employee_name": "David Mckee", "department": "Marketing", "state": "CA", "salary": 99732, "age": 56, "bonus": 52816, "ts": 124328789}'
# create_topic-1:0:220: key=None value=b'{"emp_id": "05dbb698-c27e-4c6f-8ce9-2e62981d9516", "employee_name": "Bryan Young", "department": "IT", "state": "RJ", "salary": 46426, "age": 58, "bonus": 15603, "ts": 1520145361}'
# create_topic-1:0:221: key=None value=b'{"emp_id": "c48a213d-8b77-4073-95cb-58bb6ba373a7", "employee_name": "Tracy Washington", "department": "Sales", "state": "TX", "salary": 37725, "age": 49, "bonus": 90345, "ts": 370191998}'
# create_topic-1:0:222: key=None value=b'{"emp_id": "f64c6b8b-db53-482d-81e2-16de330a10c6", "employee_name": "Mr. James Robinson DVM", "department": "Marketing", "state": "TX", "salary": 111885, "age": 55, "bonus": 2309, "ts": 1689239207}'
# create_topic-1:0:223: key=None value=b'{"emp_id": "943d0608-a72b-4e95-b137-73260aa9b37e", "employee_name": "Matthew Reyes", "department": "HR", "state": "FL", "salary": 45356, "age": 36, "bonus": 77860, "ts": 659193136}'
# create_topic-1:0:224: key=None value=b'{"emp_id": "a786a8e5-1247-444f-9c3f-3ecb94c47d7b", "employee_name": "Audrey Martin", "department": "IT", "state": "TX", "salary": 136469, "age": 49, "bonus": 656, "ts": 858257614}'
# create_topic-1:0:225: key=None value=b'{"emp_id": "dd5b8af1-a1d8-4530-a98a-f37459f13fde", "employee_name": "Mrs. Rebecca Williams DVM", "department": "Sales", "state": "IL", "salary": 96777, "age": 26, "bonus": 46934, "ts": 619503982}'
# create_topic-1:0:226: key=None value=b'{"emp_id": "96e19e2e-68f8-42b5-bcdf-37740cfd58c5", "employee_name": "Sarah Gray", "department": "Sales", "state": "TX", "salary": 93686, "age": 27, "bonus": 61757, "ts": 1000408109}'
# create_topic-1:0:227: key=None value=b'{"emp_id": "2a8287f3-2bd1-4852-a15b-bdc4f60f9dc6", "employee_name": "Shannon Hansen", "department": "HR", "state": "NY", "salary": 144139, "age": 33, "bonus": 85961, "ts": 1357411932}'
# create_topic-1:0:228: key=None value=b'{"emp_id": "9a1bc36e-20be-4f3f-b817-f12c62c25cef", "employee_name": "Sydney Norton", "department": "IT", "state": "RJ", "salary": 62264, "age": 57, "bonus": 50917, "ts": 156899161}'
# create_topic-1:0:229: key=None value=b'{"emp_id": "11e3e319-17e3-4d82-9e4f-53317e7fecfe", "employee_name": "Nathan Harrington", "department": "Sales", "state": "NY", "salary": 63563, "age": 45, "bonus": 45103, "ts": 299737984}'
# create_topic-1:0:230: key=None value=b'{"emp_id": "5389f3c0-9a14-429b-8880-7c6da14def26", "employee_name": "Chris Clark", "department": "IT", "state": "CA", "salary": 133415, "age": 47, "bonus": 58472, "ts": 710214264}'
# create_topic-1:0:231: key=None value=b'{"emp_id": "c4aa1595-1092-48ae-95cd-ca62fee62ed4", "employee_name": "Nicholas Anderson", "department": "IT", "state": "IL", "salary": 59770, "age": 22, "bonus": 30374, "ts": 1319718258}'
# create_topic-1:0:232: key=None value=b'{"emp_id": "5f951bbc-9b31-4d43-9f5f-4da280600333", "employee_name": "Patrick Davies", "department": "IT", "state": "RJ", "salary": 97898, "age": 23, "bonus": 42194, "ts": 793034650}'
# create_topic-1:0:233: key=None value=b'{"emp_id": "b0428838-97dc-4458-948d-d55feb311936", "employee_name": "Dr. Ashley Santiago", "department": "Sales", "state": "RJ", "salary": 47934, "age": 38, "bonus": 90288, "ts": 1613139787}'
# create_topic-1:0:234: key=None value=b'{"emp_id": "24179fb4-f270-4090-babd-8bb06af88b68", "employee_name": "Jessica Carroll", "department": "Sales", "state": "IL", "salary": 43646, "age": 27, "bonus": 84133, "ts": 874539592}'
# create_topic-1:0:235: key=None value=b'{"emp_id": "cfa61816-78bd-4b6a-85d3-607a184140f1", "employee_name": "Gary Wright", "department": "IT", "state": "NY", "salary": 128914, "age": 45, "bonus": 63465, "ts": 256129680}'
# create_topic-1:0:236: key=None value=b'{"emp_id": "ade1cd04-1998-4f5a-bf96-b1d0c16d7791", "employee_name": "Jesse Nunez", "department": "Marketing", "state": "FL", "salary": 63923, "age": 40, "bonus": 27298, "ts": 489754995}'
# create_topic-1:0:237: key=None value=b'{"emp_id": "f07e401a-7373-4b3b-aa7e-8bb356a0647e", "employee_name": "Cody Brock", "department": "HR", "state": "CA", "salary": 72486, "age": 44, "bonus": 78404, "ts": 192830586}'
# create_topic-1:0:238: key=None value=b'{"emp_id": "f329e32e-96d7-43b2-bf94-93d56360466a", "employee_name": "Katelyn Mendoza", "department": "Marketing", "state": "CA", "salary": 52142, "age": 25, "bonus": 23573, "ts": 1554631912}'
# create_topic-1:0:239: key=None value=b'{"emp_id": "790fde00-91ba-4567-8fce-e116926a42a9", "employee_name": "Brian Wright", "department": "HR", "state": "CA", "salary": 42045, "age": 22, "bonus": 87509, "ts": 262859608}'
# create_topic-1:0:240: key=None value=b'{"emp_id": "d9f8912e-bc4c-4893-aada-f9ef19a89c5e", "employee_name": "Brian Jackson", "department": "Marketing", "state": "TX", "salary": 142552, "age": 25, "bonus": 75355, "ts": 252164242}'
# create_topic-1:0:241: key=None value=b'{"emp_id": "07a07da3-a81a-4302-9468-24b8549fde6f", "employee_name": "Bradley Hicks", "department": "Sales", "state": "CA", "salary": 63114, "age": 50, "bonus": 24545, "ts": 773958887}'
# create_topic-1:0:242: key=None value=b'{"emp_id": "bdbc5e4d-1571-43cf-b5bd-1bfd091df299", "employee_name": "James Anderson", "department": "Sales", "state": "IL", "salary": 129128, "age": 36, "bonus": 15798, "ts": 345751049}'
# create_topic-1:0:243: key=None value=b'{"emp_id": "2c826f9a-ea6d-4668-8d5f-caa8b8d7d608", "employee_name": "Alexis Mueller", "department": "HR", "state": "NY", "salary": 120276, "age": 22, "bonus": 40271, "ts": 67895056}'
# create_topic-1:0:244: key=None value=b'{"emp_id": "4ab7d581-cb25-42fc-a484-d05b3bae52a9", "employee_name": "Sandra Jones", "department": "HR", "state": "TX", "salary": 25270, "age": 58, "bonus": 50169, "ts": 595190562}'
# create_topic-1:0:245: key=None value=b'{"emp_id": "27a65ae0-c349-4181-a35e-9d5561ebcc8e", "employee_name": "Danielle Torres", "department": "Sales", "state": "NY", "salary": 83038, "age": 57, "bonus": 80537, "ts": 1227685861}'
# create_topic-1:0:246: key=None value=b'{"emp_id": "7318d268-1dba-4384-a4df-b2353b66a7aa", "employee_name": "Virginia Powell", "department": "IT", "state": "RJ", "salary": 97419, "age": 40, "bonus": 74503, "ts": 997620125}'
# create_topic-1:0:247: key=None value=b'{"emp_id": "996cfd9b-c427-41bd-bd7d-60076f961b3c", "employee_name": "Jeremy Ellis", "department": "Marketing", "state": "RJ", "salary": 103611, "age": 47, "bonus": 28179, "ts": 1241987992}'
# create_topic-1:0:248: key=None value=b'{"emp_id": "bce35426-dfc7-4b52-adb5-283a63281f2f", "employee_name": "Jaime Wong", "department": "HR", "state": "RJ", "salary": 134990, "age": 27, "bonus": 68167, "ts": 515601195}'
# create_topic-1:0:249: key=None value=b'{"emp_id": "11f7d530-19a9-47cd-b5dd-9e13b936c3e6", "employee_name": "Tina Preston", "department": "Marketing", "state": "CA", "salary": 72534, "age": 50, "bonus": 88290, "ts": 331593123}'
# create_topic-1:0:250: key=None value=b'{"emp_id": "df69a4f7-1a7f-4c73-9135-bf9eb9ee9368", "employee_name": "Mark Frost", "department": "Marketing", "state": "CA", "salary": 57041, "age": 46, "bonus": 20608, "ts": 409680409}'
# create_topic-1:0:251: key=None value=b'{"emp_id": "ecc30ddf-3a97-4305-b81b-660d62d5f7ee", "employee_name": "Larry Sanchez", "department": "HR", "state": "FL", "salary": 16243, "age": 40, "bonus": 55436, "ts": 519683007}'
# ...
# create_topic-1:0:345: key=None value=b'{"emp_id": "094ec826-3117-4b55-84fc-8b2eb5930171", "employee_name": "Heather Ponce", "department": "Sales", "state": "NY", "salary": 50712, "age": 18, "bonus": 31444, "ts": 1496707539}'
# create_topic-1:0:346: key=None value=b'{"emp_id": "e7869c78-641c-4d6c-9f4f-84704df3fda7", "employee_name": "Karen Davis", "department": "Marketing", "state": "TX", "salary": 109369, "age": 19, "bonus": 54953, "ts": 982641530}'
# create_topic-1:0:347: key=None value=b'{"emp_id": "b7c1e6c5-5782-4b41-a6ce-b5a69e8cd795", "employee_name": "Laurie Moore", "department": "Marketing", "state": "FL", "salary": 140311, "age": 55, "bonus": 3686, "ts": 93825688}'
# create_topic-1:0:348: key=None value=b'{"emp_id": "eeff88b0-3718-4b44-9f52-1aadc99ef116", "employee_name": "Daniel Fisher", "department": "IT", "state": "IL", "salary": 56728, "age": 30, "bonus": 52059, "ts": 1654659727}'
# create_topic-1:0:349: key=None value=b'{"emp_id": "43587884-1390-4788-94aa-957cd2f181ca", "employee_name": "Shelley Henry", "department": "IT", "state": "RJ", "salary": 43976, "age": 40, "bonus": 3773, "ts": 906844988}'
# create_topic-1:0:350: key=None value=b'{"emp_id": "d7d650f1-9ca0-4241-9de6-e6668497173d", "employee_name": "Renee Anderson", "department": "IT", "state": "TX", "salary": 87586, "age": 30, "bonus": 35900, "ts": 910096417}'
# create_topic-1:0:351: key=None value=b'{"emp_id": "6d4efe96-1122-488c-a32f-6246da9aab94", "employee_name": "Christopher Russell", "department": "Marketing", "state": "NY", "salary": 100206, "age": 43, "bonus": 50616, "ts": 604281415}'
# create_topic-1:0:352: key=None value=b'{"emp_id": "2d2a35af-8a4b-4dca-a505-943aa9db3be4", "employee_name": "Johnny Lewis", "department": "Sales", "state": "TX", "salary": 17764, "age": 55, "bonus": 77876, "ts": 645070088}'
# create_topic-1:0:353: key=None value=b'{"emp_id": "85f48f41-109c-4b89-a33f-4df0303fc16d", "employee_name": "Jamie Mcneil", "department": "IT", "state": "NY", "salary": 19444, "age": 56, "bonus": 28869, "ts": 660873875}'
# create_topic-1:0:354: key=None value=b'{"emp_id": "fa483958-55e8-43c4-af12-da47184f73a4", "employee_name": "Matthew Jones", "department": "HR", "state": "RJ", "salary": 59809, "age": 42, "bonus": 72507, "ts": 281065470}'
# create_topic-1:0:355: key=None value=b'{"emp_id": "d14760fd-1263-47b8-9022-81b0bb873c36", "employee_name": "Ralph Griffin", "department": "Sales", "state": "IL", "salary": 102170, "age": 42, "bonus": 33358, "ts": 1613801727}'
# create_topic-1:0:356: key=None value=b'{"emp_id": "0e5c7443-8193-4d25-8501-1716e3afdb60", "employee_name": "Karl Dominguez", "department": "IT", "state": "CA", "salary": 63219, "age": 20, "bonus": 33774, "ts": 1406256646}'
# create_topic-1:0:357: key=None value=b'{"emp_id": "6ee9b7f9-71d5-4be5-8fa4-906385896f5b", "employee_name": "Kenneth Nixon", "department": "HR", "state": "NY", "salary": 44887, "age": 33, "bonus": 58074, "ts": 1045645064}'
# create_topic-1:0:358: key=None value=b'{"emp_id": "62f6f312-3e9b-4ecb-aaa0-4157fc3a7872", "employee_name": "Adam Johnson", "department": "Marketing", "state": "RJ", "salary": 147002, "age": 48, "bonus": 17251, "ts": 1318498143}'
# create_topic-1:0:359: key=None value=b'{"emp_id": "f058a2f6-4dcf-4288-9715-967ae148f168", "employee_name": "Jessica Smith", "department": "HR", "state": "IL", "salary": 43144, "age": 46, "bonus": 54075, "ts": 1457108491}'
# create_topic-1:0:360: key=None value=b'{"emp_id": "9dc2e3d1-4bd0-4685-a70c-fd40bd76fba7", "employee_name": "Adrian Huff", "department": "Marketing", "state": "RJ", "salary": 141325, "age": 29, "bonus": 17245, "ts": 944246015}'
# create_topic-1:0:361: key=None value=b'{"emp_id": "4f1eedbc-ab69-405e-aa65-67b3553f21c4", "employee_name": "Cassandra Romero", "department": "Marketing", "state": "TX", "salary": 124551, "age": 22, "bonus": 68542, "ts": 549657313}'
# create_topic-1:0:362: key=None value=b'{"emp_id": "a775bd2a-64a6-48d1-b702-d1e459fc9960", "employee_name": "Christopher Maynard", "department": "Marketing", "state": "TX", "salary": 31212, "age": 37, "bonus": 76568, "ts": 1043805799}'
# create_topic-1:0:363: key=None value=b'{"emp_id": "965a30df-0262-4106-a11d-f2b18c95d94b", "employee_name": "Brandon Pacheco", "department": "Marketing", "state": "FL", "salary": 139454, "age": 47, "bonus": 93439, "ts": 465233030}'
# create_topic-1:0:364: key=None value=b'{"emp_id": "61182e22-930f-4fa1-b681-cc8068fbe125", "employee_name": "Jonathan Barnes", "department": "Marketing", "state": "FL", "salary": 124639, "age": 20, "bonus": 93869, "ts": 1254076726}'
# create_topic-1:0:365: key=None value=b'{"emp_id": "873aff53-7290-4f56-8f72-9bb525a3f925", "employee_name": "Joseph Johnson", "department": "Sales", "state": "CA", "salary": 81831, "age": 42, "bonus": 2927, "ts": 1337571577}'
# create_topic-1:0:366: key=None value=b'{"emp_id": "621a7bc0-0e5f-48bf-a708-1ad5196a8fa8", "employee_name": "Joseph Steele", "department": "HR", "state": "TX", "salary": 85274, "age": 40, "bonus": 24506, "ts": 567261293}'
# create_topic-1:0:367: key=None value=b'{"emp_id": "f4f983c3-d858-4490-b278-7c2b70c2cdcf", "employee_name": "Teresa Carlson", "department": "Marketing", "state": "TX", "salary": 138667, "age": 33, "bonus": 12795, "ts": 1465946057}'
# create_topic-1:0:368: key=None value=b'{"emp_id": "c1e539f2-3bd1-414b-aec4-cbb3b492f145", "employee_name": "Laura Jones", "department": "Marketing", "state": "CA", "salary": 72829, "age": 59, "bonus": 1331, "ts": 1660826322}'
# create_topic-1:0:369: key=None value=b'{"emp_id": "a8a04211-4b9f-4973-9935-9379448a8dbc", "employee_name": "Sarah Murphy", "department": "HR", "state": "RJ", "salary": 142521, "age": 57, "bonus": 84990, "ts": 1674068986}'
# create_topic-1:0:370: key=None value=b'{"emp_id": "9378970d-2c9a-41b4-934d-026b39a6c216", "employee_name": "Tricia Perez", "department": "HR", "state": "CA", "salary": 100387, "age": 43, "bonus": 67819, "ts": 708709551}'
# create_topic-1:0:371: key=None value=b'{"emp_id": "e614f2cd-0e15-4f19-b4fc-b9fbd929a0bf", "employee_name": "Kristi Jones", "department": "HR", "state": "IL", "salary": 88672, "age": 43, "bonus": 9644, "ts": 1252676169}'
# create_topic-1:0:372: key=None value=b'{"emp_id": "f83ef720-f943-4888-8c54-b4eb92300ed7", "employee_name": "Jamie Carlson", "department": "IT", "state": "NY", "salary": 128801, "age": 46, "bonus": 28024, "ts": 1714617163}'
# create_topic-1:0:373: key=None value=b'{"emp_id": "34a53fec-df04-424b-a9e0-21fba2b5a7f3", "employee_name": "Anthony Ross", "department": "IT", "state": "NY", "salary": 105104, "age": 31, "bonus": 97727, "ts": 571607637}'
# create_topic-1:0:374: key=None value=b'{"emp_id": "6eb72aa0-237d-451f-b20e-07866c7f5a55", "employee_name": "Allen Rodgers", "department": "Marketing", "state": "CA", "salary": 113079, "age": 25, "bonus": 58740, "ts": 26359121}'
# create_topic-1:0:375: key=None value=b'{"emp_id": "bd05661d-fb02-44f2-ad0e-d5842756ed2e", "employee_name": "John Walton", "department": "Sales", "state": "FL", "salary": 92664, "age": 43, "bonus": 78854, "ts": 1307048343}'
# create_topic-1:0:376: key=None value=b'{"emp_id": "bcb081fb-caea-4f97-b2d5-cfeac0b604fc", "employee_name": "Kelly Gallegos", "department": "Sales", "state": "NY", "salary": 141284, "age": 23, "bonus": 79880, "ts": 1200137048}'
# create_topic-1:0:377: key=None value=b'{"emp_id": "897db043-738b-4188-9882-a2bab8cf0922", "employee_name": "Melissa Hansen", "department": "IT", "state": "CA", "salary": 32431, "age": 37, "bonus": 10559, "ts": 713518874}'
# create_topic-1:0:378: key=None value=b'{"emp_id": "e9019bbb-ff5b-4ce8-a316-1ce4d91569ec", "employee_name": "Christina Floyd", "department": "Sales", "state": "RJ", "salary": 18294, "age": 35, "bonus": 39364, "ts": 786447964}'
# create_topic-1:0:379: key=None value=b'{"emp_id": "a1fd99cf-cfc2-43e1-8094-8a6eed6bbad1", "employee_name": "Alexander Hill", "department": "Sales", "state": "CA", "salary": 101330, "age": 55, "bonus": 34658, "ts": 746985297}'
# create_topic-1:0:380: key=None value=b'{"emp_id": "0085822c-f36d-4e0d-b9f5-a691f9090fce", "employee_name": "Ms. Cassandra Hunt", "department": "Sales", "state": "IL", "salary": 57238, "age": 42, "bonus": 85307, "ts": 1635548443}'
# create_topic-1:0:381: key=None value=b'{"emp_id": "61e44e90-f087-4d74-9526-3ae851c353bb", "employee_name": "Brandi Cruz", "department": "Sales", "state": "NY", "salary": 20257, "age": 59, "bonus": 69187, "ts": 588193564}'
# create_topic-1:0:382: key=None value=b'{"emp_id": "ed4528e3-c750-4405-b870-39d80e2711b4", "employee_name": "Scott Patterson", "department": "IT", "state": "CA", "salary": 23356, "age": 34, "bonus": 53431, "ts": 452645896}'
# create_topic-1:0:383: key=None value=b'{"emp_id": "4be6521f-e37c-4d7c-84bc-54cdc9e41062", "employee_name": "Laura Adams", "department": "Marketing", "state": "FL", "salary": 148035, "age": 21, "bonus": 79253, "ts": 755825558}'
# create_topic-1:0:384: key=None value=b'{"emp_id": "4288e0a5-2ab3-4f9f-b129-d1a99f961134", "employee_name": "Laurie Williams", "department": "Marketing", "state": "IL", "salary": 58216, "age": 50, "bonus": 16952, "ts": 1486982487}'
# create_topic-1:0:385: key=None value=b'{"emp_id": "aa8780ad-9328-43de-86dd-76b976ee7aad", "employee_name": "Kelly Hooper", "department": "HR", "state": "RJ", "salary": 107867, "age": 58, "bonus": 18073, "ts": 504317865}'
# create_topic-1:0:386: key=None value=b'{"emp_id": "d4a9f650-da8b-4b56-b7f9-8d8397b16063", "employee_name": "Christopher Schwartz", "department": "HR", "state": "IL", "salary": 88146, "age": 29, "bonus": 86682, "ts": 631751269}'
# create_topic-1:0:387: key=None value=b'{"emp_id": "c8afce0f-ea36-4b74-8556-3599f5efae4e", "employee_name": "Ruben Cline", "department": "HR", "state": "FL", "salary": 31339, "age": 51, "bonus": 98380, "ts": 666266710}'
# create_topic-1:0:388: key=None value=b'{"emp_id": "873cbdb4-6e5b-4cf3-9834-66739143ddf6", "employee_name": "Michelle Walter", "department": "Sales", "state": "RJ", "salary": 11548, "age": 48, "bonus": 83404, "ts": 677931778}'
# create_topic-1:0:389: key=None value=b'{"emp_id": "4c41e9db-6190-4220-b21a-fee4396a1655", "employee_name": "Bryan Douglas", "department": "Sales", "state": "IL", "salary": 127547, "age": 31, "bonus": 56612, "ts": 1136864697}'
# create_topic-1:0:390: key=None value=b'{"emp_id": "dae7d540-817a-4344-9c3a-f878f2082a36", "employee_name": "Scott Le", "department": "HR", "state": "FL", "salary": 115829, "age": 51, "bonus": 97156, "ts": 663656302}'
# create_topic-1:0:391: key=None value=b'{"emp_id": "e0ad5ff3-27cb-4199-b387-18efad415b45", "employee_name": "Mary Orozco", "department": "Marketing", "state": "CA", "salary": 54971, "age": 48, "bonus": 33690, "ts": 577311342}'
# create_topic-1:0:392: key=None value=b'{"emp_id": "bf9b553b-980d-4757-9ad2-fb98109886a7", "employee_name": "Heather Vargas", "department": "Marketing", "state": "CA", "salary": 44211, "age": 25, "bonus": 38950, "ts": 141031010}'
# create_topic-1:0:393: key=None value=b'{"emp_id": "3cc8845c-896e-4079-bc7e-c81c45df2086", "employee_name": "Kristy Lucas", "department": "Sales", "state": "FL", "salary": 138278, "age": 41, "bonus": 72214, "ts": 603196441}'
# create_topic-1:0:394: key=None value=b'{"emp_id": "76cc5eeb-7203-4f0d-932d-83539f3f00f4", "employee_name": "Jared Morgan", "department": "HR", "state": "FL", "salary": 101965, "age": 43, "bonus": 83416, "ts": 1278614918}'
# create_topic-1:0:395: key=None value=b'{"emp_id": "438b562d-1bf4-4184-b693-b2293905dda8", "employee_name": "Krista Campbell", "department": "HR", "state": "RJ", "salary": 147001, "age": 42, "bonus": 11038, "ts": 413575581}'
# create_topic-1:0:396: key=None value=b'{"emp_id": "62ca860f-48ec-4cae-82c9-b0484401dd23", "employee_name": "Sean Smith", "department": "Marketing", "state": "IL", "salary": 71513, "age": 19, "bonus": 93350, "ts": 1211796146}'
# create_topic-1:0:397: key=None value=b'{"emp_id": "b407ff0a-35fb-48b5-8f9d-1443d58c790c", "employee_name": "Jimmy Spears", "department": "IT", "state": "FL", "salary": 47022, "age": 23, "bonus": 62364, "ts": 11170777}'
# create_topic-1:0:398: key=None value=b'{"emp_id": "48f12a36-1b38-4483-8337-1c8d2a68b7c4", "employee_name": "Douglas Vance", "department": "Marketing", "state": "CA", "salary": 35160, "age": 52, "bonus": 34794, "ts": 905304152}'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 for message in consumer:
#       2     print ("%s:%d:%d: key=%s value=%s" % (message.topic, message.partition,
#       3                                           message.offset, message.key,
#       4                                           message.value))
#
# File /opt/conda/lib/python3.10/site-packages/kafka/consumer/group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File /opt/conda/lib/python3.10/site-packages/kafka/consumer/group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File /opt/conda/lib/python3.10/site-packages/kafka/consumer/group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File /opt/conda/lib/python3.10/site-packages/kafka/consumer/group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File /opt/conda/lib/python3.10/site-packages/kafka/consumer/group.py:702, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     699     self._client.poll(timeout_ms=0)
#     701 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702 self._client.poll(timeout_ms=timeout_ms)
#     703 # after the long poll, we should check whether the group needs to rebalance
#     704 # prior to returning data so that the group can stabilize faster
#     705 if self._coordinator.need_rejoin():
#
# File /opt/conda/lib/python3.10/site-packages/kafka/client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File /opt/conda/lib/python3.10/site-packages/kafka/client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File /opt/conda/lib/python3.10/selectors.py:469, in EpollSelector.select(self, timeout)
#     467 ready = []
#     468 try:
# --> 469     fd_event_list = self._selector.poll(timeout, max_ev)
#     470 except InterruptedError:
#     471     return ready
#
# KeyboardInterrupt:

# %%
from kafka import TopicPartition

consumer = KafkaConsumer(group_id='dibimbing-group',
                         bootstrap_servers=[f'{kafka_host}:9092'],
                         value_deserializer=lambda m: json.loads(m.decode('ascii')),
                         auto_offset_reset='earliest',
                         enable_auto_commit=False
                        )
consumer.assign([TopicPartition(kafka_topic_partition, 2)])

# %%
for message in consumer:
    print ("%s:%d:%d: key=%s value=%s" % (message.topic, message.partition,
                                          message.offset, message.key,
                                          message.value))

# %%
consumer.seek_to_beginning()

# %%
for message in consumer:
    print ("%s:%d:%d: key=%s value=%s" % (message.topic, message.partition,
                                          message.offset, message.key,
                                          message.value))
